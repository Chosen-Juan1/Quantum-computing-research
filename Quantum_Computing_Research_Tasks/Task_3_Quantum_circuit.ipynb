# %% [markdown]
# Multiple Gates

# %% [markdown]
# Can you meassure between circuits?

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import plot_histogram

qc = QuantumCircuit(2)
qc.h(0)
sampler = StatevectorSampler()
qc.measure_all()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'01': 494, '00': 530}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %% [markdown]
# Two gates

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
sampler = StatevectorSampler()
qc.measure_all()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'00': 511, '11': 513}

# %%
counts = result[0].data.meas.get_counts()
plot_histogram(counts)

# %% [markdown]
# Three gates

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.y(1)
sampler = StatevectorSampler()
qc.measure_all()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'10': 496, '01': 528}

# %%
counts = result[0].data.meas.get_counts()
plot_histogram(counts)

# %% [markdown]
# What if we do it indivudually?

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import plot_histogram

qc = QuantumCircuit(2)
qc.h(0)
sampler = StatevectorSampler()
qc.measure_all()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'00': 519, '01': 505}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %%
qc = QuantumCircuit(2)
qc.cx(0,1)
qc.measure_all()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'00': 1024}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.measure_all()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'01': 1024}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %% [markdown]
# Im going to use the pauli gates for simplicity

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import plot_histogram

qc = QuantumCircuit(2)
qc.h(0)
sample2 = StatevectorSampler()
qc.measure_all()
result = sample2.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'01': 522, '00': 502}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.measure_all()
result = sample2.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 
2
qc.draw("mpl")
# Out:
# {'01': 1024}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %%
qc = QuantumCircuit(2)
qc.y(0)
qc.measure_all()
result = sample2.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'01': 1024}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %%
qc = QuantumCircuit(2)
qc.z(0)
qc.measure_all()
result = sample2.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

 

qc.draw("mpl")
# Out:
# {'00': 1024}

# %%
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)

# %% [markdown]
# ------------------------------new attempt------------------------------------------

# %%
import numpy as np
from qiskit.visualization import plot_bloch_multivector

alpha = 1/2
beta = np.sqrt(3)/2

sv = Statevector([alpha, beta])
plot_bloch_multivector(sv)

# %%
sv = Statevector.from_label("0")

qc1 = QuantumCircuit(1)
qc1.h(0)
sv = sv.evolve(qc1)
qc1.draw("mpl")

# %%
import matplotlib.pyplot as plt
probs = sv.probabilities_dict()
plot_histogram(probs)

# %%
qc2 = QuantumCircuit(1)
qc2.z(0)
sv = sv.evolve(qc2)

qc3 = QuantumCircuit(1)
qc3.h(0)
sv = sv.evolve(qc3)

print(sv.probabilities_dict())
