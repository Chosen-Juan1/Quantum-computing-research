# %%
# Source - https://stackoverflow.com/a/15622021
# Posted by tyleha, modified by community. See post 'Timeline' for change history
# Retrieved 2026-02-02, License - CC BY-SA 4.0

# %pip install qiskit
# %pip install qiskit-aer
# %pip install qiskit-ibm-runtime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
from qiskit.quantum_info import Statevector

# %%
qc = QuantumCircuit(1)
qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# Pauli-X gate

# %%
qc = QuantumCircuit(1)
qc.x(0)

qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# Pauli-Y gate

# %%
qc = QuantumCircuit(1)
qc.y(0)
qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# Pauli-Z gate

# %%
qc = QuantumCircuit(1)
qc.z(0)
qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# Hadaman gate

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# Controlled-Not gate (CNOT)

# %%
qc = QuantumCircuit(2)
qc.cx(0, 1)  # control = qubit 0, target = qubit 1

qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# Trying out gates with arbitrary amplitudes

# %%
import numpy as np
from qiskit.visualization import plot_bloch_multivector

alpha = 1/2
beta = np.sqrt(3)/2

Original_state = Statevector([alpha, beta])
plot_bloch_multivector(Original_state)

# %% [markdown]
# amplitude pre-gates

# %%
print(Original_state.data)
# Out:
# [0.5      +0.j 0.8660254+0.j]

# %%
qc = QuantumCircuit(1)
qc.initialize(Original_state.data, 0)
qc.x(0)
qc.draw("mpl")

# %%
dir(Statevector)
# Out:
# ['_ATOL_DEFAULT',
#  '_MAX_TOL',
#  '_RTOL_DEFAULT',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_abc_impl',
#  '_add',
#  '_evolve_instruction',
#  '_evolve_operator',
#  '_expectation_value_pauli',
#  '_index_to_ket_array',
#  '_ipython_display_',
#  '_matrix_to_dict',
#  '_multiply',
#  '_rng',
# ...

# %%
from qiskit.visualization import plot_histogram
qc.measure_all()
result = Original_state.run([qc], shots=1024).result()
One_gate_Output = result[0].data.meas.get_counts()
plot_histogram(One_gate_Output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 from qiskit.visualization import plot_histogram
#       2 qc.measure_all()
# ----> 3 result = Original_state.run([qc], shots=1024).result()
#       4 One_gate_Output = result[0].data.meas.get_counts()
#       5 plot_histogram(One_gate_Output)
#
# AttributeError: 'Statevector' object has no attribute 'run'

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# amplitudes after applying x-gate

# %%
print(state.data)
# Out:
# [0.8660254+0.j 0.5      +0.j]

# %%
qc.y(0)
qc.h(0)
qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# data after applying y and hadaman gates

# %%
print(state.data)
# Out:
# [0.+0.25881905j 0.-0.96592583j]
